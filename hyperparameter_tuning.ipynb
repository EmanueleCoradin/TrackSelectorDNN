# %%
# !pwd
# Out:
# /eos/home-i03/e/ecoradin/GitHub/TrackSelectorDNN

# %%
# !python3 cluster/submit_job.py > tune.log 2>&1

# %%
# !pip freeze > requirements.txt

# %%
# !pip install -e /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/TrackSelectorDNN
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///eos/user/e/ecoradin/GitHub/TrackSelectorDNN/TrackSelectorDNN
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: TrackSelectorDNN
#     Found existing installation: TrackSelectorDNN 0.1
#     Uninstalling TrackSelectorDNN-0.1:
#       Successfully uninstalled TrackSelectorDNN-0.1
#   DEPRECATION: Legacy editable install of TrackSelectorDNN==0.1 from file:///eos/user/e/ecoradin/GitHub/TrackSelectorDNN/TrackSelectorDNN (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
# ...

# %%
from TrackSelectorDNN.tune import tune
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-11-03 12:55:54</td></tr>
# <tr><td>Running for: </td><td>00:00:23.72        </td></tr>
# <tr><td>Memory:      </td><td>67.1/1007.5 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/30 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:H100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# ...

# %%
tune.load_config("base.yaml")
# Out:
# Config(hit_input_dim=4, track_feat_dim=4, latent_dim=16, pooling_type='sum', netA_hidden_dim=32, netA_hidden_layers=2, netA_batchnorm=True, netA_activation='silu', netB_hidden_dim=64, netB_hidden_layers=2, netB_batchnorm=True, netB_activation='silu', lr=0.001, epochs=10, batch_size=64, dataset_type='dummy', train_path='data/processed/tracks_train.pt', n_tracks=2000, max_hits=15, val_fraction=0.2)

# %%
from tune import tune
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from tune import tune
#
# ModuleNotFoundError: No module named 'tune'

# %%
# !python3 -m TrackSelectorDNN.tune.tune
# Out:
# 2025-11-03 12:56:59,602	INFO worker.py:2004 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# /eos/user/e/ecoradin/.local/lib/python3.11/site-packages/ray/_private/worker.py:2052: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 2025-11-03 12:57:02,506	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# ╭──────────────────────────────────────────────────────────────────╮
# │ Configuration for experiment     trainable_2025-11-03_12-56-44   │
# ├──────────────────────────────────────────────────────────────────┤
# │ Search algorithm                 BasicVariantGenerator           │
# ...
